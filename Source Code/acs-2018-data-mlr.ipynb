# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt

import statsmodels.api as sm
from statsmodels.stats import diagnostic as diag
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.decomposition import PCA
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df=pd.read_csv('imputedData2018.csv')

# %%
df=df.set_index('id')
df.head()
# Out:
#                       Estimate!!EMPLOYMENT STATUS!!Population 16 years and over  \
# id
# 1400000US36001000100                                             1505.0
# 1400000US36001000200                                             3748.0
# 1400000US36001000300                                             4816.0
# 1400000US36001000401                                             2305.0
# 1400000US36001000403                                             3756.0
#
#                       Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force  \
# id
# 1400000US36001000100                                              930.0
# 1400000US36001000200                                             2519.0
# 1400000US36001000300                                             2894.0
# 1400000US36001000401                                             1000.0
# 1400000US36001000403                                             2747.0
#
#                       Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Civilian labor force!!Unemployed  \
# id
# 1400000US36001000100                                              113.0
# 1400000US36001000200                                              242.0
# 1400000US36001000300                                              296.0
# 1400000US36001000401                                               50.0
# 1400000US36001000403                                               78.0
#
#                       Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Armed Forces  \
# id
# 1400000US36001000100                                                6.0
# 1400000US36001000200                                                0.0
# 1400000US36001000300                                                0.0
# 1400000US36001000401                                                0.0
# 1400000US36001000403                                                0.0
#
#                       Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!Not in labor force  \
# id
# 1400000US36001000100                                              575.0
# 1400000US36001000200                                             1229.0
# 1400000US36001000300                                             1922.0
# 1400000US36001000401                                             1305.0
# 1400000US36001000403                                             1009.0
#
#                       Estimate!!EMPLOYMENT STATUS!!Civilian labor force  \
# id
# 1400000US36001000100                                              924.0
# 1400000US36001000200                                             2519.0
# 1400000US36001000300                                             2894.0
# 1400000US36001000401                                             1000.0
# 1400000US36001000403                                             2747.0
#
#                       Estimate!!EMPLOYMENT STATUS!!Females 16 years and over  \
# id
# 1400000US36001000100                                              816.0
# 1400000US36001000200                                             2051.0
# 1400000US36001000300                                             2536.0
# 1400000US36001000401                                             1434.0
# 1400000US36001000403                                             1875.0
#
#                       Estimate!!EMPLOYMENT STATUS!!Females 16 years and over!!In labor force  \
# id
# 1400000US36001000100                                              521.0
# 1400000US36001000200                                             1549.0
# 1400000US36001000300                                             1405.0
# 1400000US36001000401                                              574.0
# 1400000US36001000403                                             1268.0
#
#                       Estimate!!EMPLOYMENT STATUS!!Females 16 years and over!!In labor force!!Civilian labor force  \
# id
# 1400000US36001000100                                              521.0
# 1400000US36001000200                                             1549.0
# 1400000US36001000300                                             1405.0
# 1400000US36001000401                                              574.0
# 1400000US36001000403                                             1268.0
#
#                       Estimate!!EMPLOYMENT STATUS!!Females 16 years and over!!In labor force!!Civilian labor force!!Employed  \
# id
# 1400000US36001000100                                              432.0
# 1400000US36001000200                                             1421.0
# 1400000US36001000300                                             1361.0
# 1400000US36001000401                                              546.0
# 1400000US36001000403                                             1202.0
#
#                       ...  \
# id                    ...
# 1400000US36001000100  ...
# 1400000US36001000200  ...
# 1400000US36001000300  ...
# 1400000US36001000401  ...
# 1400000US36001000403  ...
#
#                       Estimate!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population!!Civilian noninstitutionalized population 19 to 64 years!!In labor force!!Unemployed!!With health insurance coverage!!With private health insurance  \
# id
# 1400000US36001000100                                               13.0
# 1400000US36001000200                                              104.0
# 1400000US36001000300                                               32.0
# 1400000US36001000401                                               28.0
# 1400000US36001000403                                               43.0
#
#                       Estimate!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population!!Civilian noninstitutionalized population 19 to 64 years!!In labor force!!Unemployed!!With health insurance coverage!!With public coverage  \
# id
# 1400000US36001000100                                               62.0
# 1400000US36001000200                                               81.0
# 1400000US36001000300                                              156.0
# 1400000US36001000401                                               22.0
# 1400000US36001000403                                               21.0
#
#                       Estimate!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population!!Civilian noninstitutionalized population 19 to 64 years!!In labor force!!Unemployed!!No health insurance coverage  \
# id
# 1400000US36001000100                                                0.0
# 1400000US36001000200                                               54.0
# 1400000US36001000300                                               46.0
# 1400000US36001000401                                               22.0
# 1400000US36001000403                                                0.0
#
#                       Estimate!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population!!Civilian noninstitutionalized population 19 to 64 years!!Not in labor force  \
# id
# 1400000US36001000100                                              338.0
# 1400000US36001000200                                              900.0
# 1400000US36001000300                                              998.0
# 1400000US36001000401                                              172.0
# 1400000US36001000403                                              483.0
#
#                       Estimate!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population!!Civilian noninstitutionalized population 19 to 64 years!!Not in labor force!!With health insurance coverage  \
# id
# 1400000US36001000100                                              300.0
# 1400000US36001000200                                              658.0
# 1400000US36001000300                                              803.0
# 1400000US36001000401                                              146.0
# 1400000US36001000403                                              483.0
#
#                       Estimate!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population!!Civilian noninstitutionalized population 19 to 64 years!!Not in labor force!!With health insurance coverage!!With private health insurance  \
# id
# 1400000US36001000100                                               75.0
# 1400000US36001000200                                               88.0
# 1400000US36001000300                                              333.0
# 1400000US36001000401                                               91.0
# 1400000US36001000403                                              287.0
#
#                       Estimate!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population!!Civilian noninstitutionalized population 19 to 64 years!!Not in labor force!!With health insurance coverage!!With public coverage  \
# id
# 1400000US36001000100                                              255.0
# 1400000US36001000200                                              587.0
# 1400000US36001000300                                              526.0
# 1400000US36001000401                                               73.0
# 1400000US36001000403                                              262.0
#
#                       Estimate!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population!!Civilian noninstitutionalized population 19 to 64 years!!Not in labor force!!No health insurance coverage  \
# id
# 1400000US36001000100                                               38.0
# 1400000US36001000200                                              242.0
# 1400000US36001000300                                              195.0
# 1400000US36001000401                                               26.0
# 1400000US36001000403                                                0.0
#
#                       Percent Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All families  \
# id
# 1400000US36001000100                                               24.2
# 1400000US36001000200                                               34.3
# 1400000US36001000300                                               21.7
# 1400000US36001000401                                                2.0
# 1400000US36001000403                                                2.4
#
#                       Percent Estimate!!EMPLOYMENT STATUS!!Civilian labor force!!Unemployment Rate
# id
# 1400000US36001000100                                               12.2
# 1400000US36001000200                                                9.6
# 1400000US36001000300                                               10.2
# 1400000US36001000401                                                5.0
# 1400000US36001000403                                                2.8
#
# [5 rows x 115 columns]

# %%
X=df.drop('Percent Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All families',axis=1)
Y=df[['Percent Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All families']]
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=0)

# %%
scaler = StandardScaler()
# Fit on training set only.
scaler.fit(X_train)
# Apply transform to both the training set and the test set.
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
pca = PCA(.95)

# %%
pca.fit(X_train)
X_train = pca.transform(X_train)
X_test = pca.transform(X_test)

# %%
X_train.shape
# Out:
# (3880, 39)

# %%
regression_model = LinearRegression()

# pass through the X_train & y_train data set
regression_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_predict = regression_model.predict(X_test)

# %%
import math
# calculate the mean squared error
model_mse = mean_squared_error(y_test, y_predict)

# calculate the mean absolute error
model_mae = mean_absolute_error(y_test, y_predict)

# calulcate the root mean squared error
model_rmse =  math.sqrt(model_mse)

# display the output
print("MSE {:.3}".format(model_mse))
print("MAE {:.3}".format(model_mae))
print("RMSE {:.3}".format(model_rmse))
# Out:
# MSE 35.3
# MAE 3.72
# RMSE 5.94

# %%
model_r2 = r2_score(y_test, y_predict)
print(model_r2)
# Out:
# 0.7488819629637546

# %%
scaler1 = StandardScaler()
pca1= PCA(0.95)
scaler1.fit(X)
X1 = scaler1.transform(X)
pca1.fit(X1)
X1= pca1.transform(X1)
xtr,xte,ytr,yte=train_test_split(X1, Y, test_size=0.20, random_state=0)

# %%
X1.shape
# Out:
# (4851, 40)

# %%
#print(X1)
X2 = sm.add_constant(X1)

# create a OLS model
model = sm.OLS(Y, X2)

# fit the data
est = model.fit()

# %%
print(est.summary())
#['x3','x4','x11','x12','x13','x24','x25','x26','x27','x28','x39','x40','x42','x58','x59','x56','x54','x53','x44']
# Out:
#                                                                                    OLS Regression Results
# ===========================================================================================================================================================================================
# Dep. Variable:     Percent Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All families   R-squared:                       0.783
# Model:                                                                                                                                         OLS   Adj. R-squared:                  0.781
# Method:                                                                                                                              Least Squares   F-statistic:                     432.9
# Date:                                                                                                                             Thu, 05 Nov 2020   Prob (F-statistic):               0.00
# Time:                                                                                                                                     06:37:05   Log-Likelihood:                -15140.
# No. Observations:                                                                                                                             4851   AIC:                         3.036e+04
# Df Residuals:                                                                                                                                 4810   BIC:                         3.063e+04
# Df Model:                                                                                                                                       40
# Covariance Type:                                                                                                                         nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         11.8204      0.079    149.444      0.000      11.665      11.975
# x1            -0.1859      0.012    -15.563      0.000      -0.209      -0.162
# x2            -1.7699      0.017   -103.416      0.000      -1.803      -1.736
# x3             1.4629      0.028     52.684      0.000       1.408       1.517
# x4             0.1370      0.040      3.396      0.001       0.058       0.216
# x5            -0.9102      0.041    -22.056      0.000      -0.991      -0.829
# x6             0.7630      0.050     15.346      0.000       0.666       0.861
# x7             0.4333      0.057      7.637      0.000       0.322       0.545
# x8            -0.8912      0.058    -15.279      0.000      -1.005      -0.777
# x9            -1.7874      0.062    -28.908      0.000      -1.909      -1.666
# x10            0.0210      0.071      0.296      0.767      -0.118       0.161
# x11           -1.4164      0.073    -19.533      0.000      -1.559      -1.274
# x12            0.1630      0.079      2.073      0.038       0.009       0.317
# x13            0.7886      0.080      9.908      0.000       0.633       0.945
# x14            0.6646      0.080      8.270      0.000       0.507       0.822
# x15            0.2369      0.083      2.854      0.004       0.074       0.400
# x16           -0.6953      0.084     -8.248      0.000      -0.861      -0.530
# x17           -0.7848      0.085     -9.214      0.000      -0.952      -0.618
# x18           -0.6328      0.088     -7.156      0.000      -0.806      -0.459
# x19            0.2512      0.091      2.747      0.006       0.072       0.431
# x20            0.4581      0.093      4.912      0.000       0.275       0.641
# x21            0.3205      0.096      3.344      0.001       0.133       0.508
# x22            0.3546      0.100      3.542      0.000       0.158       0.551
# x23           -0.0108      0.102     -0.106      0.916      -0.212       0.190
# x24            0.0328      0.103      0.318      0.751      -0.170       0.235
# x25            0.4393      0.103      4.249      0.000       0.237       0.642
# x26           -0.4916      0.108     -4.542      0.000      -0.704      -0.279
# x27            0.0406      0.111      0.367      0.714      -0.176       0.257
# x28           -0.7967      0.112     -7.094      0.000      -1.017      -0.577
# x29           -0.1153      0.114     -1.009      0.313      -0.339       0.109
# x30           -0.6382      0.115     -5.527      0.000      -0.865      -0.412
# x31           -0.8678      0.116     -7.467      0.000      -1.096      -0.640
# x32            0.0684      0.118      0.581      0.562      -0.163       0.300
# x33            1.0425      0.120      8.697      0.000       0.807       1.277
# x34            1.3569      0.122     11.096      0.000       1.117       1.597
# x35           -1.2466      0.127     -9.822      0.000      -1.495      -0.998
# x36           -0.8774      0.128     -6.874      0.000      -1.128      -0.627
# x37            0.1466      0.129      1.139      0.255      -0.106       0.399
# x38           -0.2516      0.132     -1.912      0.056      -0.510       0.006
# x39            1.7140      0.136     12.591      0.000       1.447       1.981
# x40            2.1591      0.139     15.478      0.000       1.886       2.433
# ==============================================================================
# Omnibus:                     3128.625   Durbin-Watson:                   1.756
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           177218.722
# Skew:                           2.395   Prob(JB):                         0.00
# Kurtosis:                      32.221   Cond. No.                         11.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# MODEL WITHOUT INCOME PREDICTORS

# %%
cols = [c for c in df.columns if c.find('INCOME AND BENEFITS')==-1]
col2 = [c for c in df.columns if c.find('With Social Security')!=-1 or c.find('cash public assistance')!=-1 or c.find('SNAP benefits')!=-1]
cols=cols+col2
dfx=df[cols]
dfx.shape
# Out:
# (4851, 76)

# %%
X=dfx.drop('Percent Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All families',axis=1)
Y=dfx[['Percent Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All families']]
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=0)

# %%
scaler = StandardScaler()
# Fit on training set only.
scaler.fit(X_train)
# Apply transform to both the training set and the test set.
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
pca = PCA(.95)
pca.fit(X_train)
X_train = pca.transform(X_train)
X_test = pca.transform(X_test)

# %%
regression_model = LinearRegression()

# pass through the X_train & y_train data set
regression_model.fit(X_train, y_train)
y_predict = regression_model.predict(X_test)

# %%
model_mse = mean_squared_error(y_test, y_predict)

# calculate the mean absolute error
model_mae = mean_absolute_error(y_test, y_predict)

# calulcate the root mean squared error
model_rmse =  math.sqrt(model_mse)

# display the output
print("MSE {:.3}".format(model_mse))
print("MAE {:.3}".format(model_mae))
print("RMSE {:.3}".format(model_rmse))
model_r2 = r2_score(y_test, y_predict)
print("R-squared:", model_r2)
# Out:
# MSE 46.9
# MAE 4.61
# RMSE 6.85
# R-squared: 0.6670028280675495

# %%
scaler1 = StandardScaler()
pca1= PCA(0.95)
scaler1.fit(X)
X1 = scaler1.transform(X)
pca1.fit(X1)
X1= pca1.transform(X1)
xtr,xte,ytr,yte=train_test_split(X1, Y, test_size=0.20, random_state=0)

# %%
X2 = sm.add_constant(X1)

# create a OLS model
model = sm.OLS(Y, X2)

# fit the data
est = model.fit()
print(est.summary())
# Out:
#                                                                                    OLS Regression Results
# ===========================================================================================================================================================================================
# Dep. Variable:     Percent Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All families   R-squared:                       0.693
# Model:                                                                                                                                         OLS   Adj. R-squared:                  0.692
# Method:                                                                                                                              Least Squares   F-statistic:                     389.6
# Date:                                                                                                                             Thu, 05 Nov 2020   Prob (F-statistic):               0.00
# Time:                                                                                                                                     06:37:05   Log-Likelihood:                -15974.
# No. Observations:                                                                                                                             4851   AIC:                         3.201e+04
# Df Residuals:                                                                                                                                 4822   BIC:                         3.219e+04
# Df Model:                                                                                                                                       28
# Covariance Type:                                                                                                                         nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         11.8204      0.094    126.006      0.000      11.636      12.004
# x1            -0.1464      0.016     -9.099      0.000      -0.178      -0.115
# x2             2.7683      0.031     89.196      0.000       2.707       2.829
# x3             0.7188      0.041     17.482      0.000       0.638       0.799
# x4            -0.8782      0.053    -16.621      0.000      -0.982      -0.775
# x5             1.8657      0.064     29.051      0.000       1.740       1.992
# x6             0.5529      0.069      7.997      0.000       0.417       0.688
# x7            -1.3697      0.072    -18.956      0.000      -1.511      -1.228
# x8            -0.5877      0.077     -7.620      0.000      -0.739      -0.437
# x9             0.3428      0.086      3.987      0.000       0.174       0.511
# x10            0.1018      0.089      1.150      0.250      -0.072       0.275
# x11           -0.0720      0.095     -0.758      0.449      -0.258       0.114
# x12           -0.7178      0.097     -7.402      0.000      -0.908      -0.528
# x13            0.0469      0.100      0.469      0.639      -0.149       0.243
# x14           -0.0697      0.106     -0.656      0.512      -0.278       0.139
# x15           -0.1142      0.108     -1.058      0.290      -0.326       0.097
# x16           -0.6901      0.113     -6.112      0.000      -0.912      -0.469
# x17            1.5799      0.115     13.721      0.000       1.354       1.806
# x18            0.2987      0.127      2.358      0.018       0.050       0.547
# x19           -1.0570      0.127     -8.301      0.000      -1.307      -0.807
# x20           -0.0913      0.135     -0.679      0.497      -0.355       0.172
# x21           -0.1874      0.136     -1.375      0.169      -0.455       0.080
# x22            0.1919      0.138      1.391      0.164      -0.079       0.463
# x23            1.0695      0.140      7.629      0.000       0.795       1.344
# x24           -1.9028      0.142    -13.436      0.000      -2.180      -1.625
# x25           -0.7019      0.146     -4.816      0.000      -0.988      -0.416
# x26            1.6550      0.151     10.969      0.000       1.359       1.951
# x27            1.0964      0.154      7.120      0.000       0.795       1.398
# x28           -1.9237      0.157    -12.267      0.000      -2.231      -1.616
# ==============================================================================
# Omnibus:                     2401.583   Durbin-Watson:                   1.763
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            55917.751
# Skew:                           1.847   Prob(JB):                         0.00
# Kurtosis:                      19.217   Cond. No.                         9.75
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
